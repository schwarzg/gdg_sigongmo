# %%
import numpy as np
import pandas as pd

# %%
list = pd.read_csv("wine_data.csv")
list.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
name_list =[]
df = pd.DataFrame(list)

# %%
df.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
des = df['description']
des[1]
testing = des[1].split()


des_list = []
for i in range(0,len(des)):
    temp = des[i].split()
    L = len(temp)-1
    for j in range(0,L):
        des_list.append(temp[j].lower())
        
des_unique = set(des_list)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-143-49c2ac5e5d77> in <module>
# ----> 1 dddd = list(des_unique)
#
# TypeError: 'DataFrame' object is not callable

# %%
LL = 0
for i in range(0,len(des_unique)):
    if des_unique[i] == '2022–2030.' :
        print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-138-7aba8eb2370c> in <module>
#       1 LL = 0
#       2 for i in range(0,len(des_unique)):
# ----> 3     if des_unique[i] == '2022–2030.' :
#       4         print(i)
#
# TypeError: 'set' object does not support indexing

# %%
testing
# Out:
# ['Ripe',
#  'aromas',
#  'of',
#  'fig,',
#  'blackberry',
#  'and',
#  'cassis',
#  'are',
#  'softened',
#  'and',
#  'sweetened',
#  'by',
#  'a',
#  'slathering',
#  'of',
#  'oaky',
#  'chocolate',
#  'and',
#  'vanilla.',
#  'This',
#  'is',
#  'full,',
#  'layered,',
#  'intense',
#  'and',
#  'cushioned',
#  'on',
#  'the',
#  'palate,',
#  'with',
#  'rich',
#  'flavors',
#  'of',
#  'chocolaty',
#  'black',
#  'fruits',
#  'and',
#  'baking',
#  'spices.',
#  'A',
#  'toasty,',
#  'everlasting',
#  'finish',
#  'is',
#  'heady',
#  'but',
#  'ideally',
#  'balanced.',
#  'Drink',
#  'through',
#  '2023.']

# %%
redun = len(des_list) - len(des_unique)
print(len(des_list), len(des_unique),redun)
print(LL/len(des))
# Out:
# 5913917 67667 5846250
# 40.18317763201484

# %%
des_unique
# Out:
# {'20+',
#  'ever',
#  'awesomely',
#  'ager.',
#  'witness',
#  "prime's",
#  "morel's",
#  'encompasses',
#  'boisset-owned',
#  "veeder's",
#  'zingarelli',
#  'food-friendly.',
#  'agility',
#  'artist/writer',
#  'yost',
#  'driller,',
#  'honey—and',
#  'aroma-wise:',
#  'padri',
#  'extruding',
#  '“modern,”',
#  "midolini's",
#  'pop',
#  'mike.',
#  'obvious',
#  'fine-honed',
#  "varozza's",
#  'o•s',
#  'complicated,',
#  'bigtime.',
#  'racked',
#  'gurgue,',
#  'too:',
#  'ximenez',
#  'ponderous',
#  'gracianos',
#  'barbarian',
#  'sweetened.',
#  'bordering',
#  'hot-afternoon',
#  'square-bottomed',
#  'signalling',
#  'gevrey',
#  '1,250',
#  'low-to-mid',
#  'spark',
#  'ends,',
#  'tropical-fruit-driven',
#  'cab-42%',
#  'dazzler,',
#  'jarring.',
#  'conero',
#  'culprit',
#  'tri-vin',
#  'all-time',
#  'chock',
#  'peach-and-herb',
#  'lose',
#  'true,',
#  'fruited.',
#  "z's",
#  '2020,',
#  'inimitable',
#  'reagan',
#  'ebullience.',
#  'slick,',
# ...

# %%
char_out = {w : i for i, w in enumerate(des_unique)}
char_in = {i : w for i, w in enumerate(des_unique)}
char_in
# Out:
# {0: '20+',
#  1: 'ever',
#  2: 'awesomely',
#  3: 'ager.',
#  4: 'witness',
#  5: "prime's",
#  6: "morel's",
#  7: 'encompasses',
#  8: 'boisset-owned',
#  9: "veeder's",
#  10: 'zingarelli',
#  11: 'food-friendly.',
#  12: 'agility',
#  13: 'artist/writer',
#  14: 'yost',
#  15: 'driller,',
#  16: 'honey—and',
#  17: 'aroma-wise:',
#  18: 'padri',
#  19: 'extruding',
#  20: '“modern,”',
#  21: "midolini's",
#  22: 'pop',
#  23: 'mike.',
#  24: 'obvious',
#  25: 'fine-honed',
#  26: "varozza's",
#  27: 'o•s',
#  28: 'complicated,',
#  29: 'bigtime.',
#  30: 'racked',
#  31: 'gurgue,',
#  32: 'too:',
#  33: 'ximenez',
#  34: 'ponderous',
#  35: 'gracianos',
#  36: 'barbarian',
#  37: 'sweetened.',
#  38: 'bordering',
#  39: 'hot-afternoon',
#  40: 'square-bottomed',
#  41: 'signalling',
#  42: 'gevrey',
#  43: '1,250',
#  44: 'low-to-mid',
#  45: 'spark',
#  46: 'ends,',
#  47: 'tropical-fruit-driven',
#  48: 'cab-42%',
#  49: 'dazzler,',
#  50: 'jarring.',
#  51: 'conero',
# ...

# %%
char_out['2022–2030.']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-159-ccba23f9e17c> in <module>
# ----> 1 char_out['2022–2030.']
#
# KeyError: '2022–2030.'

# %%
hiden_size = len(des_unique) # 각 층 출력 크기
num_classes = len(des_unique) # 분류 층 수
sequence_length =

# %%
a=np.zeros([1,67667])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c84d17ff3eb8> in <module>
# ----> 1 a=np.zeros([1,67667])
#
# NameError: name 'np' is not defined

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
for i, w in enumerate(des[0].split()):
    num= char_out[w.lower()]
    
    a=np.zeros([1,len(des_unique)])
    a[0,num-1]=0
    
    if i==0:
        vec=a
    else:
        vec=np.concatenate((vec,a), axis=0)
    #print(char_out[des[0].split()[i]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-148-1c7d744aeca1> in <module>
#       1 for i, w in enumerate(des[0].split()):
# ----> 2     num= char_out[w.lower()]
#       3
#       4     a=np.zeros([1,len(des_unique)])
#       5     a[0,num-1]=0
#
# KeyError: '2022–2030.'

# %%
from keras.layers.recurrent import SimpleRNN
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(SimpleRNN(n_hidden,
                   init = weight_variable,
                   input_shape = (maxlen, n_out)))
model.add(Dense(n_out, init = weight_variable))
modell.add(Activation('linear'))
optimizer = Adam(lr = 0.001, beta_1 = 0.9, beta_2 = 0.999)
model-compile(loss = 'mean_squared_error',
             optimizer = optimizer)

epochs = 
batch_size =

# %%
model.fit(X_train, Y_train,
         batch_size = batch_size,
         epechs = epochs,
         validation_data = (X_validation, Y_vlaidation),
         callbacks = [early_stopping])
